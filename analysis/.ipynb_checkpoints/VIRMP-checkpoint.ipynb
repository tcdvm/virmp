# %%
import pandas as pd; import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; seaborn.set()
import re
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-284477daa7bc> in <module>()
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
#       3 import matplotlib.pyplot as plt
# ----> 4 import seaborn as sns; seaborn.set()
#       5 import re
#
# NameError: name 'seaborn' is not defined

# %%
df = pd.read_json('items.jl', lines=True, dtype=False)

# %%
# Reorder the columns
df = df[['name', 'total_annual_cases', 'avg_daily_cases', 'avg_daily_outpatient_cases', 'avg_daily_inpatient_cases', 'avg_daily_surgeries', 'avg_daily_ER_cases']]
df
# Out:
#                                                 name total_annual_cases  \
# 0                       Angell Animal Medical Center              77629
# 1                       Angell Animal Medical Center               2400
# 2                         Alvarado Veterinary Clinic              60000
# 3                  Affiliated Veterinary Specialists              12000
# 4                    Advanced Veterinary Specialists              12045
# 5                         1st Pet Veterinary Centers              37000
# 6                         Arbutus West Animal Clinic               1500
# 7                            Animal Medical Hospital              36500
# 8                          The Animal Medical Center              51000
# 9  Animal Emergency and Referral Center of Minnesota              16104
#
#   avg_daily_cases avg_daily_outpatient_cases avg_daily_inpatient_cases  \
# 0             212                        153                        59
# 1              10                         10                         0
# 2             160                        115                        45
# 3              40                         35                        25
# 4              33                         20                        15
# 5             100                         60                        20
# 6            8-12                      10-12                         1
# 7             100                         80                         8
# 8             145                        125                        50
# 9              43                         28                        15
#
#   avg_daily_surgeries avg_daily_ER_cases
# 0                  20                 62
# 1                   2                  1
# 2                  22                  5
# 3                   8                  5
# 4                   5                 10
# 5                   6                 50
# 6                   1                0.1
# 7                   5                 24
# 8                  10                 45
# 9                   4                 25

# %%
# Get rid of commas in total_annual_cases and ">" (e.g. > 20,000)
df['total_annual_cases'] = df['total_annual_cases'].str.replace(',', '')
df['total_annual_cases'] = df['total_annual_cases'].str.replace('>', '')
df['avg_daily_cases'] = df['avg_daily_cases'].str.replace('+', '')
df['avg_daily_ER_cases'] = df['avg_daily_ER_cases'].str.replace('+', '')

# %%
df
# Out:
#                                                 name total_annual_cases  \
# 0                       Angell Animal Medical Center              77629
# 1                       Angell Animal Medical Center               2400
# 2                         Alvarado Veterinary Clinic              60000
# 3                  Affiliated Veterinary Specialists              12000
# 4                    Advanced Veterinary Specialists              12045
# 5                         1st Pet Veterinary Centers              37000
# 6                         Arbutus West Animal Clinic               1500
# 7                            Animal Medical Hospital              36500
# 8                          The Animal Medical Center              51000
# 9  Animal Emergency and Referral Center of Minnesota              16104
#
#   avg_daily_cases avg_daily_outpatient_cases avg_daily_inpatient_cases  \
# 0             212                        153                        59
# 1              10                         10                         0
# 2             160                        115                        45
# 3              40                         35                        25
# 4              33                         20                        15
# 5             100                         60                        20
# 6            8-12                      10-12                         1
# 7             100                         80                         8
# 8             145                        125                        50
# 9              43                         28                        15
#
#   avg_daily_surgeries avg_daily_ER_cases
# 0                  20                 62
# 1                   2                  1
# 2                  22                  5
# 3                   8                  5
# 4                   5                 10
# 5                   6                 50
# 6                   1                0.1
# 7                   5                 24
# 8                  10                 45
# 9                   4                 25

# %%
# Define function to convert range (e.g. 10000-15000) to one value the average of the two values
def range_to_mean(range_str):
    range_str = range_str.replace(" ", "")
    match = re.search('(\d+)-(\d+)', range_str)
    if match:
        lower = match.group(1)
        upper = match.group(2)
        average = (float(lower)+float(upper))/2
        print(range_str)
        return average
    else:
        return float(range_str)

# %%
total_annual_cases_adj = df['total_annual_cases'].apply(range_to_mean)

# %%
df.insert(2, 'total_annual_cases_adj', total_annual_cases_adj)

# %%
df
# Out:
#                                                 name total_annual_cases  \
# 0                       Angell Animal Medical Center              77629
# 1                       Angell Animal Medical Center               2400
# 2                         Alvarado Veterinary Clinic              60000
# 3                  Affiliated Veterinary Specialists              12000
# 4                    Advanced Veterinary Specialists              12045
# 5                         1st Pet Veterinary Centers              37000
# 6                         Arbutus West Animal Clinic               1500
# 7                            Animal Medical Hospital              36500
# 8                          The Animal Medical Center              51000
# 9  Animal Emergency and Referral Center of Minnesota              16104
#
#    total_annual_cases_adj avg_daily_cases avg_daily_outpatient_cases  \
# 0                 77629.0             212                        153
# 1                  2400.0              10                         10
# 2                 60000.0             160                        115
# 3                 12000.0              40                         35
# 4                 12045.0              33                         20
# 5                 37000.0             100                         60
# 6                  1500.0            8-12                      10-12
# 7                 36500.0             100                         80
# 8                 51000.0             145                        125
# 9                 16104.0              43                         28
#
#   avg_daily_inpatient_cases avg_daily_surgeries avg_daily_ER_cases
# 0                        59                  20                 62
# 1                         0                   2                  1
# 2                        45                  22                  5
# 3                        25                   8                  5
# 4                        15                   5                 10
# 5                        20                   6                 50
# 6                         1                   1                0.1
# 7                         8                   5                 24
# 8                        50                  10                 45
# 9                        15                   4                 25

# %%
df.sort_values(by='total_annual_cases_adj').plot(kind="barh", x="name", y="total_annual_cases_adj")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-3bbb987f7e0e> in <module>()
# ----> 1 df.sort_values(by='total_annual_cases_adj').plot(kind="barh", x="name", y="total_annual_cases_adj")
#
# ~/dev/virtualenvs/scrapy/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2675                           fontsize=fontsize, colormap=colormap, table=table,
#    2676                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2677                           sort_columns=sort_columns, **kwds)
#    2678     __call__.__doc__ = plot_frame.__doc__
#    2679
#
# ~/dev/virtualenvs/scrapy/lib/python3.6/site-packages/pandas/plotting/_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1900                  yerr=yerr, xerr=xerr,
#    1901                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1902                  **kwds)
#    1903
#    1904
#
# ~/dev/virtualenvs/scrapy/lib/python3.6/site-packages/pandas/plotting/_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1725                             pass
#    1726                 data = series
# -> 1727         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1728
#    1729     plot_obj.generate()
#
# ~/dev/virtualenvs/scrapy/lib/python3.6/site-packages/pandas/plotting/_core.py in __init__(self, data, **kwargs)
#    1172
#    1173         self.log = kwargs.pop('log', False)
# -> 1174         MPLPlot.__init__(self, data, **kwargs)
#    1175
#    1176         if self.stacked or self.subplots:
#
# ~/dev/virtualenvs/scrapy/lib/python3.6/site-packages/pandas/plotting/_core.py in __init__(self, data, kind, by, subplots, sharex, sharey, use_index, figsize, grid, legend, rot, ax, fig, title, xlim, ylim, xticks, yticks, sort_columns, fontsize, secondary_y, colormap, table, layout, **kwds)
#      98                  table=False, layout=None, **kwds):
#      99
# --> 100         _converter._WARN = False
#     101         self.data = data
#     102         self.by = by
#
# NameError: name '_converter' is not defined

# %%
# Adjust average daily cases
avg_daily_cases_adj = df['avg_daily_cases'].apply(range_to_mean)
df.insert(4, 'avg_daily_cases_adj', avg_daily_cases_adj)
# Out:
# 8-12
# 30-40
# 30-50
# 60-90
# 120-160
# 20-50
# 40-42
# 30-45
# 40-65
# 80-100
# 20-25
# 15-25
# 15-20
# 80-100
# 30-35
# 125-150
# 10-12
# 90-100
# 40-50
# 45-60
# 95-110
# 30-35
# 90-110
# 15-30
# 15-30
# 80-120
# 40-50

# %%
# Adjust average daily outpatient cases
avg_daily_outpatient_cases_adj = df['avg_daily_outpatient_cases'].apply(range_to_mean)
df.insert(6, 'avg_daily_outpatient_cases_adj', avg_daily_outpatient_cases_adj)
# Out:
# 10-12
# 25-35
# 20-40
# 50-70
# 85-115
# 20-30
# 20-30
# 20-40
# 40-50
# 15-20
# 10-30
# 10-15
# 60-80
# 25-30
# 75-80
# 25-30
# 20-30
# 20-30
# 30-35
# 80-90
# 20-35
# 40-50
# 10-20
# 10-20
# 40-60
# 25-35

# %%
# Adjust average daily inpatient cases
avg_daily_inpatient_cases_adj = df['avg_daily_inpatient_cases'].apply(range_to_mean)
df.insert(8, 'avg_daily_inpatient_cases_adj', avg_daily_inpatient_cases_adj)
# Out:
# 10-12
# 15-30
# 15-20
# 25-65
# 7-20
# 8-15
# 10-30
# 50-60
# 10-15
# 5-15
# 10-15
# 20-40
# 5-8
# 55-60
# 10-12
# 10-20
# 8-15
# 15-20
# 15-20
# 12-15
# 8-12
# 10-15
# 10-30
# 30-45
# 7-15
# 7-15
# 20-40
# 15-25

# %%
# Adjust average daily surgeries
avg_daily_surgeries_adj = df['avg_daily_surgeries'].apply(range_to_mean)
df.insert(10, 'avg_daily_surgeries_adj', avg_daily_surgeries_adj)
# Out:
# 6-10
# 4-9
# 7-9
# 2-6
# 5-12
# 3-9
# 10-15
# 6-8
# 8-15
# 4-9
# 15-20
# 1-3
# 3-5
# 3-5
# 3-5
# 3-4
# 3-5
# 5-8
# 3-4
# 10-20
# 2-5
# 15-20
# 2-3
# 6-8
# 10-16
# 3-5
# 5-10
# 3-4
# 3-4
# 4-8/
# 4-8
# 4-7
# 8-10
# 2-4
# 5-6
# 3-4
# 8-12
# 2-5
# 3-6
# 3-6
# 20-30
# 6-10
# 4-5

# %%
# Adjust average daily ER cases
avg_daily_ER_cases_adj = df['avg_daily_ER_cases'].apply(range_to_mean)
df.insert(12, 'avg_daily_ER_cases_adj', avg_daily_ER_cases_adj)
# Out:
# 15-20
# 5-15
# 10-15
# 20-25
# 15-30
# 10-25
# 30-40
# 30-34
# 10-20
# 15-30
# 4-6
# 15-20
# 3-4
# 20-30
# 15-30
# 25-40
# 30-40
# 25-35
# 15-20
# 9-20
# 9-20
# 15-20
# 20-25
# 25-35
# 20-25
# 30-40
# 7-20
# 7-20
# 15-25

# %%
df
# Out:
#                                                   name total_annual_cases  \
# 0                           Arbutus West Animal Clinic               1500
# 1                              Animal Medical Hospital              36500
# 2                            The Animal Medical Center              51000
# 3    Animal Emergency and Referral Center of Minnesota              16104
# 4                         Angell Animal Medical Center              77629
# 5                         Angell Animal Medical Center               2400
# 6                           Alvarado Veterinary Clinic              60000
# 7                    Affiliated Veterinary Specialists              12000
# 8                      Advanced Veterinary Specialists              12045
# 9                           1st Pet Veterinary Centers              37000
# 10              BluePearl Veterinary Partners DC Metro              17000
# 11   Bluegrass Veterinary Specialists + Animal Emer...              15000
# 12                                               Avets              15354
# 13                                   Auburn University              16000
# 14   Atlantic Veterinary College, University of Pri...               4752
# 15               Atlantic Coast Veterinary Specialists              20000
# 16                 Aspen Meadow Veterinary Specialists               9600
# 17                               ASPCA Animal Hospital              20191
# 18   Artemis Veterinary Emergency and Specialty Ser...               3400
# 19   Arizona Veterinary Emergency & Critical Care C...              44022
# 20              BluePearl Veterinary Partners New York              57000
# 21             BluePearl Veterinary Partners Nashville              17000
# 22             BluePearl Veterinary Partners Minnesota              12000
# 23         BluePearl Veterinary Partners Michigan (SF)              25000
# 24         BluePearl Veterinary Partners Michigan (GR)              18336
# 25         BluePearl Veterinary Partners Michigan (GR)              18336
# 26              BluePearl Veterinary Partners Kirkland               9000
# 27              BluePearl Veterinary Partners Kentucky              28000
# 28               BluePearl Veterinary Partners Georgia              66000
# 29               BluePearl Veterinary Partners Florida              59000
# ..                                                 ...                ...
# 139  Veterinary Emergency and Specialty Center of N...              10000
# 140          Veterinary Emergency and Specialty Center              12180
# 141            Veterinary Emergency and Referral Group              35000
# 142                                   VESVSC Wisconsin              22072
# 143               VCA West Los Angeles Animal Hospital              40000
# 144  VCA Veterinary Referral and Emergency Center o...              20000
# 145  VCA Veterinary Care Animal Hospital and Referr...              35000
# 146    VCA Valley Animal Hospital and Emergency Center              28000
# 147  VCA Southpaws Veterinary Specialists and Emerg...              32000
# 148  Veterinary Specialty Centre of Newfoundland an...               6000
# 149  Veterinary Specialty Centre of Newfoundland an...               6000
# 150              Veterinary Specialty Center of Tucson              17000
# 151             Veterinary Specialty Center of Seattle              20000
# 152            Veterinary Specialty Center of Delaware              30000
# 153                        Veterinary Specialty Center              41600
# 154        Veterinary Specialists & Emergency Services              30000
# 155                     Veterinary Referral Associates              15000
# 156           Veterinary Medical Center of Long Island              36000
# 157      Veterinary Medical Center of Central New York              18692
# 158               Wisconsin Veterinary Referral Center              33400
# 159                         Wilson Veterinary Hospital              42000
# 160                        Wheat Ridge Animal Hospital              36000
# 161               WestVet Emergency & Specialty Center              29155
# 162             Western College of Veterinary Medicine               9224
# 163      West Hills Animal Hospital & Emergency Center              30000
# 164   Virginia-Maryland College of Veterinary Medicine              13792
# 165     Veterinary Specialty Hospital of the Carolinas              40000
# 166  Veterinary Specialty Hospital of San Diego - N...              11268
# 167         Veterinary Specialty Hospital of San Diego              22000
# 168  University of Wisconsin-Madison School of Vete...              24937
#
#      total_annual_cases_adj avg_daily_cases  avg_daily_cases_adj  \
# 0                    1500.0            8-12                 10.0
# 1                   36500.0             100                100.0
# 2                   51000.0             145                145.0
# 3                   16104.0              43                 43.0
# 4                   77629.0             212                212.0
# 5                    2400.0              10                 10.0
# 6                   60000.0             160                160.0
# 7                   12000.0              40                 40.0
# 8                   12045.0              33                 33.0
# 9                   37000.0             100                100.0
# 10                  17000.0              40                 40.0
# 11                  15000.0           30-40                 35.0
# 12                  15354.0              42                 42.0
# 13                  16000.0              60                 60.0
# 14                   4752.0              20                 20.0
# 15                  20000.0              35                 35.0
# 16                   9600.0              24                 24.0
# 17                  20191.0              51                 51.0
# 18                   3400.0              10                 10.0
# 19                  44022.0             120                120.0
# 20                  57000.0             156                156.0
# 21                  17000.0              60                 60.0
# 22                  12000.0           30-50                 40.0
# 23                  25000.0              70                 70.0
# 24                  18336.0              51                 51.0
# 25                  18336.0              51                 51.0
# 26                   9000.0              55                 55.0
# 27                  28000.0           60-90                 75.0
# 28                  66000.0             180                180.0
# 29                  59000.0         120-160                140.0
# ..                      ...             ...                  ...
# 139                 10000.0              30                 30.0
# 140                 12180.0           30-35                 32.5
# 141                 35000.0          90-110                100.0
# 142                 22072.0              60                 60.0
# 143                 40000.0             110                110.0
# 144                 20000.0              40                 40.0
# 145                 35000.0             100                100.0
# 146                 28000.0              75                 75.0
# 147                 32000.0             100                100.0
# 148                  6000.0           15-30                 22.5
# 149                  6000.0           15-30                 22.5
# 150                 17000.0              45                 45.0
# 151                 20000.0              56                 56.0
# 152                 30000.0              50                 50.0
# 153                 41600.0             120                120.0
# 154                 30000.0          80-120                100.0
# 155                 15000.0           40-50                 45.0
# 156                 36000.0              86                 86.0
# 157                 18692.0              51                 51.0
# 158                 33400.0              90                 90.0
# 159                 42000.0              40                 40.0
# 160                 36000.0             100                100.0
# 161                 29155.0              80                 80.0
# 162                  9224.0              37                 37.0
# 163                 30000.0              70                 70.0
# 164                 13792.0              53                 53.0
# 165                 40000.0              60                 60.0
# 166                 11268.0              31                 31.0
# 167                 22000.0              60                 60.0
# 168                 24937.0              96                 96.0
#
#     avg_daily_outpatient_cases  avg_daily_outpatient_cases_adj  \
# 0                        10-12                            11.0
# 1                           80                            80.0
# 2                          125                           125.0
# 3                           28                            28.0
# 4                          153                           153.0
# 5                           10                            10.0
# 6                          115                           115.0
# 7                           35                            35.0
# 8                           20                            20.0
# 9                           60                            60.0
# 10                          32                            32.0
# 11                          20                            20.0
# 12                          35                            35.0
# 13                       25-35                            30.0
# 14                          15                            15.0
# 15                          30                            30.0
# 16                          12                            12.0
# 17                          20                            20.0
# 18                           6                             6.0
# 19                          95                            95.0
# 20                         101                           101.0
# 21                          50                            50.0
# 22                       20-40                            30.0
# 23                          60                            60.0
# 24                          42                            42.0
# 25                          42                            42.0
# 26                          35                            35.0
# 27                       50-70                            60.0
# 28                         120                           120.0
# 29                      85-115                           100.0
# ..                         ...                             ...
# 139                         18                            18.0
# 140                      20-35                            27.5
# 141                      40-50                            45.0
# 142                         45                            45.0
# 143                         80                            80.0
# 144                         30                            30.0
# 145                         80                            80.0
# 146                         60                            60.0
# 147                         60                            60.0
# 148                      10-20                            15.0
# 149                      10-20                            15.0
# 150                         42                            42.0
# 151                         31                            31.0
# 152                         35                            35.0
# 153                         85                            85.0
# 154                      40-60                            50.0
# 155                      25-35                            30.0
# 156                         56                            56.0
# 157                         35                            35.0
# 158                         72                            72.0
# 159                         80                            80.0
# 160                         86                            86.0
# 161                         44                            44.0
# 162                         25                            25.0
# 163                         60                            60.0
# 164                         43                            43.0
# 165                         50                            50.0
# 166                         28                            28.0
# 167                         30                            30.0
# 168                         86                            86.0
#
#     avg_daily_inpatient_cases  avg_daily_inpatient_cases_adj  \
# 0                           1                            1.0
# 1                           8                            8.0
# 2                          50                           50.0
# 3                          15                           15.0
# 4                          59                           59.0
# 5                           0                            0.0
# 6                          45                           45.0
# 7                          25                           25.0
# 8                          15                           15.0
# 9                          20                           20.0
# 10                          8                            8.0
# 11                      10-12                           11.0
# 12                          7                            7.0
# 13                        100                          100.0
# 14                          9                            9.0
# 15                          7                            7.0
# 16                          8                            8.0
# 17                         22                           22.0
# 18                          5                            5.0
# 19                         26                           26.0
# 20                         48                           48.0
# 21                         20                           20.0
# 22                      15-30                           22.5
# 23                         15                           15.0
# 24                          9                            9.0
# 25                          9                            9.0
# 26                         35                           35.0
# 27                      15-20                           17.5
# 28                         57                           57.0
# 29                      25-65                           45.0
# ..                        ...                            ...
# 139                        12                           12.0
# 140                     10-30                           20.0
# 141                     30-45                           37.5
# 142                        15                           15.0
# 143                        30                           30.0
# 144                        20                           20.0
# 145                        20                           20.0
# 146                        20                           20.0
# 147                        30                           30.0
# 148                      7-15                           11.0
# 149                      7-15                           11.0
# 150                        20                           20.0
# 151                        25                           25.0
# 152                        15                           15.0
# 153                        30                           30.0
# 154                     20-40                           30.0
# 155                     15-25                           20.0
# 156                        32                           32.0
# 157                        16                           16.0
# 158                        25                           25.0
# 159                        45                           45.0
# 160                        12                           12.0
# 161                        30                           30.0
# 162                        12                           12.0
# 163                        15                           15.0
# 164                         7                            7.0
# 165                        20                           20.0
# 166                         6                            6.0
# 167                        30                           30.0
# 168                        23                           23.0
#
#     avg_daily_surgeries  avg_daily_surgeries_adj avg_daily_ER_cases  \
# 0                     1                      1.0                0.1
# 1                     5                      5.0                 24
# 2                    10                     10.0                 45
# 3                     4                      4.0                 25
# 4                    20                     20.0                 62
# 5                     2                      2.0                  1
# 6                    22                     22.0                  5
# 7                     8                      8.0                  5
# 8                     5                      5.0                 10
# 9                     6                      6.0                 50
# 10                    3                      3.0                 14
# 11                    3                      3.0              15-20
# 12                    2                      2.0                 32
# 13                 6-10                      8.0               5-15
# 14                    6                      6.0                  5
# 15                    4                      4.0                 15
# 16                    8                      8.0                  8
# 17                   10                     10.0                 30
# 18                    2                      2.0                 10
# 19                    7                      7.0                120
# 20                   22                     22.0                 60
# 21                    8                      8.0                 20
# 22                  4-9                      6.5                  0
# 23                    5                      5.0                 20
# 24                    3                      3.0                 22
# 25                    3                      3.0                 22
# 26                  7-9                      8.0              10-15
# 27                  2-6                      4.0              20-25
# 28                   13                     13.0                 62
# 29                 5-12                      8.5                 42
# ..                  ...                      ...                ...
# 139                 5-6                      5.5                 20
# 140                 3-4                      3.5              20-25
# 141                8-12                     10.0              30-40
# 142                 2-5                      3.5                 46
# 143                   8                      8.0                 20
# 144                   6                      6.0                 15
# 145                  10                     10.0                 40
# 146                  15                     15.0                 20
# 147                  12                     12.0                 30
# 148                 3-6                      4.5               7-20
# 149                 3-6                      4.5               7-20
# 150                   7                      7.0                 20
# 151                   6                      6.0                 30
# 152                   8                      8.0                 25
# 153                  15                     15.0                 35
# 154               20-30                     25.0                 35
# 155                6-10                      8.0              15-25
# 156                  15                     15.0                 32
# 157                   5                      5.0                 27
# 158                 4-5                      4.5                 52
# 159                  15                     15.0                 45
# 160                  10                     10.0                 40
# 161                   6                      6.0                 39
# 162                 2.5                      2.5                 17
# 163                   6                      6.0                 12
# 164                  11                     11.0                  3
# 165                   6                      6.0                 20
# 166                   2                      2.0                 14
# 167                   7                      7.0                 20
# 168                   5                      5.0                 15
#
#      avg_daily_ER_cases_adj
# 0                       0.1
# 1                      24.0
# 2                      45.0
# 3                      25.0
# 4                      62.0
# 5                       1.0
# 6                       5.0
# 7                       5.0
# 8                      10.0
# 9                      50.0
# 10                     14.0
# 11                     17.5
# 12                     32.0
# 13                     10.0
# 14                      5.0
# 15                     15.0
# 16                      8.0
# 17                     30.0
# 18                     10.0
# 19                    120.0
# 20                     60.0
# 21                     20.0
# 22                      0.0
# 23                     20.0
# 24                     22.0
# 25                     22.0
# 26                     12.5
# 27                     22.5
# 28                     62.0
# 29                     42.0
# ..                      ...
# 139                    20.0
# 140                    22.5
# 141                    35.0
# 142                    46.0
# 143                    20.0
# 144                    15.0
# 145                    40.0
# 146                    20.0
# 147                    30.0
# 148                    13.5
# 149                    13.5
# 150                    20.0
# 151                    30.0
# 152                    25.0
# 153                    35.0
# 154                    35.0
# 155                    20.0
# 156                    32.0
# 157                    27.0
# 158                    52.0
# 159                    45.0
# 160                    40.0
# 161                    39.0
# 162                    17.0
# 163                    12.0
# 164                     3.0
# 165                    20.0
# 166                    14.0
# 167                    20.0
# 168                    15.0
#
# [169 rows x 13 columns]

# %%
df.describe()
# Out:
#        total_annual_cases_adj  avg_daily_cases_adj  \
# count              169.000000           169.000000
# mean             24130.520710            67.741361
# std              17241.852449            47.413900
# min               1500.000000             8.000000
# 25%              12045.000000            40.000000
# 50%              19867.000000            55.000000
# 75%              32000.000000            86.000000
# max             100000.000000           300.000000
#
#        avg_daily_outpatient_cases_adj  avg_daily_inpatient_cases_adj  \
# count                      169.000000                     169.000000
# mean                        47.955621                      22.094675
# std                         35.900442                      16.132632
# min                          4.000000                       0.000000
# 25%                         25.000000                      11.000000
# 50%                         35.000000                      17.500000
# 75%                         62.000000                      26.000000
# max                        200.000000                     100.000000
#
#        avg_daily_surgeries_adj  avg_daily_ER_cases_adj
# count               169.000000              169.000000
# mean                  7.949704               22.314201
# std                   5.631714               15.043474
# min                   1.000000                0.000000
# 25%                   4.000000               13.500000
# 50%                   6.000000               20.000000
# 75%                  10.000000               30.000000
# max                  37.000000              120.000000

# %%
df.sort_values(by='avg_daily_cases_adj').plot(kind="barh", x="name", y="avg_daily_cases_adj", figsize=(25,50))

# %%
df.sort_values(by='avg_daily_outpatient_cases_adj').plot(kind="barh", x="name", y="avg_daily_outpatient_cases_adj", figsize=(25,50))

# %%
df.sort_values(by='avg_daily_inpatient_cases_adj').plot(kind="barh", x="name", y="avg_daily_inpatient_cases_adj", figsize=(25,50))

# %%
df.sort_values(by='avg_daily_surgies_adj').plot(kind="barh", x="name", y="avg_daily_surgies_adj", figsize=(25,50))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'avg_daily_surgies_adj'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-d82a94ee9ef6> in <module>()
# ----> 1 df.sort_values(by='avg_daily_surgies_adj').plot(kind="barh", x="name", y="avg_daily_surgies_adj", figsize=(25,50))
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3184
#    3185             by = by[0]
# -> 3186             k = self.xs(by, axis=other_axis).values
#    3187             if k.ndim == 2:
#    3188
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    2021
#    2022         if axis == 1:
# -> 2023             return self[key]
#    2024
#    2025         self._consolidate_inplace()
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# ~/anaconda3_501/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'avg_daily_surgies_adj'

# %%
df.sort_values(by='avg_daily_ER_cases_adj').plot(kind="barh", x="name", y="avg_daily_ER_cases_adj", figsize=(25,50))

# %%
df2 = pd.read_json('items2.jl', lines=True)

# %%
df2
# Out:
#    ABVP_FT  ABVP_PT  ACVIM_INTMET_PT  ACVO_PT  ACVR_PT  ACVS_PT  \
# 0      1.0      NaN              1.0        1      NaN      NaN
# 1      NaN      1.0              NaN        2      2.0      1.0
#
#                                              address  avg_daily_ER_cases  \
# 0  2809 W 16th ave, Vancouver, British Columbia V...                 0.1
# 1  3832 Monroe Road, Charlotte, North Carolina 28...                24.0
#
#   avg_daily_cases  avg_daily_inpatient_cases         ...          \
# 0            8-12                          1         ...
# 1             100                          8         ...
#
#   number_of_positions         phone  \
# 0                   1  604-736-6701
# 1                   5           NaN
#
#                                   program_categories  \
# 0  [EXOTIC/WILDLIFE/ZOO, SMALL ANIMAL MEDICINE/SU...
# 1  [EMERGENCY MEDICINE/CRITICAL CARE, SMALL ANIMA...
#
#                          program_details_url resident_support salary  \
# 0  https://www.virmp.org/Program/Detail/9673                0  35000
# 1  https://www.virmp.org/Program/Detail/9760                0  35000
#
#    tech_assigned_to_ER tech_assigned_to_ICU tech_direct_support  \
# 0                    0                    0                   1
# 1                    1                    1                   6
#
#    total_annual_cases
# 0                1500
# 1               36500
#
# [2 rows x 31 columns]
